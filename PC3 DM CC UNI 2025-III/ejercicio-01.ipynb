# %% [markdown]
# **EJERCICIO 1**

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from statsmodels.stats.outliers_influence import variance_inflation_factor

# 1. Cargar el dataset de scikit-learn
# TODO

# 2. Preprocesamiento: Selección de variables y Multicolinealidad
# El dataset original tiene 30 variables, muchas muy correlacionadas.
# Seleccionamos solo las primeras 6 para este ejemplo complejo pero legible.
# TODO

# 3. Dividir el dataset (Train/Test)
# TODO

# 4. Escalado (Estandarización)
# Statsmodels no escala automáticamente; es vital para la convergencia del modelo.
# TODO

# 5. Análisis de Multicolinealidad (VIF)
# Variables con VIF > 10 suelen indicar que el modelo es inestable.
X_vif = sm.add_constant(X_train_scaled)
vif_data = pd.DataFrame()
# TODO
print("--- Diagnóstico VIF ---")
print(vif_data)
print("-" * 30)

# 6. Construcción del Modelo con Statsmodels
# Añadimos la constante (intercepto) explícitamente
# TODO

# Ajuste con método Newton-Raphson (por defecto)
resultado = modelo.fit()

# 7. Resultados Estadísticos
print(resultado.summary())

# 8. Evaluación con Datos de Prueba
# TODO
# Predict devuelve probabilidades (0 a 1)
# TODO
# Convertimos a clases (0 o 1) usando un umbral de 0.5
# TODO

print("\n--- Reporte de Clasificación (Scikit-Learn Metrics) ---")
print(classification_report(y_test, y_pred))

# 9. Interpretación de Coeficientes (Odds Ratios)
# Exponencial de los coeficientes para entender el impacto real
# TODO
print("\n--- Odds Ratios (Interpretación) ---")
print(odds_ratios)
