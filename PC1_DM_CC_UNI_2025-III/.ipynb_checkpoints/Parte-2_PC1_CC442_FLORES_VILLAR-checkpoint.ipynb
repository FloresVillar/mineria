# %%
# PARTE2 
#%pip install mlxtend
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
import numpy as np
import pandas as pd
def fase1():
    housing = fetch_california_housing(as_frame=True)
    X = housing.frame
    y = housing.target
    print(f"el escalado es una alternativa a la normalizacion \n, los datos estan limitados  a sus magnitudes, de modo que con el normalizado \nesas magnitudes desaparacen por divisiones y nos quedamos con valores numericos")
    #print(f"X : {X}\n \n  y :{y}")
    # probando el normalizado para la columna poblacion  
    poblacion = X["Population"]
    poblacion_media = poblacion.mean()
    poblacion_sigma = poblacion.std()
    poblacion = (poblacion - poblacion_media ) / poblacion_sigma
    print(f"POBLACION:{poblacion}")
    scaler = StandardScaler()
    X_escalado = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
    return X_escalado,y
# solventando el tema de la conexion, como siempre ocurre con las librerias de python , que en ocasiones son tan quisquillosos, se necesita una buena conexion a internet

def fase2(X,y):
    #predictores de 1 a 5 variables
    lr = LinearRegression()
    efs = EFS(lr, min_features=1, max_features=5, scoring='r2',print_progress=True,cv=3) 
    efs = efs.fit(X, y)
    mejor = list(efs.best_feature_names_)
    print(f"\n La combinacion optima en la columna : {mejor}") 
    X_mejor = X[mejor]
    lr.fit(X_mejor)
    theta0 = lr.intercept_
    thetas = lr.coef_
    return theta0,thetas
    
"""X_best = X_scaled[best_features]
lr.fit(X_best, y)

# 2. Obtener los parámetros del modelo (Thetas)
theta_0 = lr.intercept_  # El intercepto o sesgo
thetas = lr.coef_        # Los coeficientes de los predictores
"""
def fase3(X,mejor):
    N , M = X.shape 
    R_2 = np.sum((y - y_pred)**2) /np.sum( y - y.mean())
    R_ajustado = 1 - (1- R_2)*(N - 1)/(N -M -1 ) 
    return 
    
def fase4():
    return 
    
if __name__=='__main__': 
    X,y = fase1()
    print(f"X : {X} m y :{y}")
    theta0,theta1 = fase2(X,y)
    fase3(X,mejor)
# Out:
# el escalado es una alternativa a la normalizacion
# , los datos estan limitados  a sus magnitudes, de modo que con el normalizado
# esas magnitudes desaparacen por divisiones y nos quedamos con valores numericos
# POBLACION:0       -0.974405
# 1        0.861418
# 2       -0.820757
# 3       -0.766010
# 4       -0.759828
#            ...
# 20635   -0.512579
# 20636   -0.944382
# 20637   -0.369528
# 20638   -0.604415
# 20639   -0.033976
# Name: Population, Length: 20640, dtype: float64
# X :          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      2.344766  0.982143  0.628559  -0.153758   -0.974429 -0.049597
# 1      2.332238 -0.607019  0.327041  -0.263336    0.861439 -0.092512
# 2      1.782699  1.856182  1.155620  -0.049016   -0.820777 -0.025843
# 3      0.932968  1.856182  0.156966  -0.049833   -0.766028 -0.050329
# 4     -0.012881  1.856182  0.344711  -0.032906   -0.759847 -0.085616
# ...         ...       ...       ...        ...         ...       ...
# ...

# %%
# Out:
# C:\Users\USUARIO\anaconda3\Lib\site-packages\sklearn\datasets\_base.py:1519: UserWarning: Retry downloading from url: https://ndownloader.figshare.com/files/5976036
#   warnings.warn(f"Retry downloading from url: {remote.url}")
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# ...
